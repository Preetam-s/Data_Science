# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#pd.options.display.max_rows = 10
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('austo_automobile.csv')

# %%
df
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 0      53    Male   Business        Married  Post Graduate                 4
# 1      53   Femal   Salaried        Married  Post Graduate                 4
# 2      53  Female   Salaried        Married  Post Graduate                 3
# 3      53  Female   Salaried        Married       Graduate                 2
# 4      53    Male   Salaried        Married  Post Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 1576   22    Male   Salaried         Single       Graduate                 2
# 1577   22    Male   Business        Married       Graduate                 4
# 1578   22    Male   Business         Single       Graduate                 2
# 1579   22    Male   Business        Married       Graduate                 3
# 1580   22    Male   Salaried        Married       Graduate                 4
#
# ...

# %%
df.shape
# Out:
# (1581, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1528 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1475 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.0+ KB

# %%
df.describe(include='all').T
# Out:
#                    count unique            top  freq          mean  \
# Age               1581.0    NaN            NaN   NaN     31.922201
# Gender              1528      4           Male  1199           NaN
# Profession          1581      2       Salaried   896           NaN
# Marital_status      1581      2        Married  1443           NaN
# Education           1581      2  Post Graduate   985           NaN
# No_of_Dependents  1581.0    NaN            NaN   NaN      2.457938
# Personal_loan       1581      2            Yes   792           NaN
# House_loan          1581      2             No  1054           NaN
# Partner_working     1581      2            Yes   868           NaN
# Salary            1581.0    NaN            NaN   NaN  60392.220114
# Partner_salary    1475.0    NaN            NaN   NaN  20225.559322
# Total_salary      1581.0    NaN            NaN   NaN  79625.996205
# Price             1581.0    NaN            NaN   NaN   35597.72296
# ...

# %%
df.Gender.value_counts()
# Female is has been mispronounced here as Femal, Femle so those need to add combined under Female
# Out:
# Male      1199
# Female     327
# Femal        1
# Femle        1
# Name: Gender, dtype: int64

# %%
df.duplicated().value_counts()
#So no duplicated , which is a good sign
# Out:
# False    1581
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.replace(['Femal','Femle'],'Female',inplace=True)
# Replacing the missed named Female Values to 'Female'

# %%
df.Gender.value_counts()
# Out:
# Male      1199
# Female     329
# Name: Gender, dtype: int64

# %%
df.isna().sum()
# Out:
# Age                   0
# Gender               53
# Profession            0
# Marital_status        0
# Education             0
# No_of_Dependents      0
# Personal_loan         0
# House_loan            0
# Partner_working       0
# Salary                0
# Partner_salary      106
# Total_salary          0
# Price                 0
# Make                  0
# dtype: int64

# %%
sns.boxplot(data=df,x='Partner_salary')
# Out:
# <AxesSubplot:xlabel='Partner_salary'>

# %%
df2 = df[df['Partner_working']=='Yes']
df2.describe()
# Out:
#               Age  No_of_Dependents        Salary  Partner_salary  \
# count  868.000000        868.000000    868.000000      852.000000
# mean    31.744240          2.582949  60281.336406    35014.906103
# std      8.350125          0.886284  15095.104030    12046.487544
# min     22.000000          1.000000  30000.000000      100.000000
# 25%     25.000000          2.000000  51375.000000    28400.000000
# 50%     29.000000          3.000000  59050.000000    32900.000000
# 75%     38.000000          3.000000  71925.000000    40300.000000
# max     54.000000          4.000000  99300.000000    80500.000000
#
#         Total_salary         Price
# count     868.000000    868.000000
# mean    95314.285714  35267.281106
# std     21870.679019  13479.532555
# min     32900.000000  18000.000000
# 25%     81000.000000  24000.000000
# 50%     94250.000000  31000.000000
# 75%    105900.000000  46000.000000
# max    171000.000000  70000.000000

# %%
df2.isna().sum()
# 16 values are null in Partner Salary these need to be imputed with the diffrence between total salary and Salary
# Out:
# Age                  0
# Gender              30
# Profession           0
# Marital_status       0
# Education            0
# No_of_Dependents     0
# Personal_loan        0
# House_loan           0
# Partner_working      0
# Salary               0
# Partner_salary      16
# Total_salary         0
# Price                0
# Make                 0
# dtype: int64

# %%
df3 = df[df['Partner_working']=='No']
df3.describe()
# Out:
#              Age  No_of_Dependents        Salary  Partner_salary  \
# count  713.00000        713.000000    713.000000           623.0
# mean    32.13885          2.305750  60527.208976             0.0
# std      8.51826          0.988236  14155.715691             0.0
# min     22.00000          0.000000  30000.000000             0.0
# 25%     25.00000          2.000000  52400.000000             0.0
# 50%     29.00000          2.000000  60100.000000             0.0
# 75%     38.00000          3.000000  71800.000000             0.0
# max     54.00000          4.000000  90700.000000             0.0
#
#        Total_salary         Price
# count    713.000000    713.000000
# mean   60527.208976  36000.000000
# std    14155.715691  13817.734086
# min    30000.000000  18000.000000
# 25%    52400.000000  25000.000000
# 50%    60100.000000  31000.000000
# 75%    71800.000000  48000.000000
# max    90700.000000  70000.000000

# %%
df3.isna().sum()
# 90 nulls  in Partner_salary since here the working partner is No , this can be imputed to 0
# Out:
# Age                  0
# Gender              23
# Profession           0
# Marital_status       0
# Education            0
# No_of_Dependents     0
# Personal_loan        0
# House_loan           0
# Partner_working      0
# Salary               0
# Partner_salary      90
# Total_salary         0
# Price                0
# Make                 0
# dtype: int64

# %%
df[df['Total_salary']>150000].sort_values(by='Total_salary',ascending=True)
# Out:
#      Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 87    51    Male   Salaried        Married  Post Graduate                 3
# 57    54    Male   Business        Married  Post Graduate                 2
# 42    52  Female   Salaried        Married  Post Graduate                 3
# 117   47    Male   Salaried        Married       Graduate                 2
# 131   46    Male   Salaried        Married  Post Graduate                 3
# 277   41    Male   Salaried        Married  Post Graduate                 3
# 2     53  Female   Salaried        Married  Post Graduate                 3
# 329   39  Female   Salaried        Married  Post Graduate                 3
# 130   46  Female   Salaried        Married  Post Graduate                 3
# 19    49    Male   Salaried        Married  Post Graduate                 3
# 99    50    Male   Salaried        Married  Post Graduate                 3
# ...

# %%
# Imputing Null Values in Parter Salary with difference between Total_salary and Salary 
df.Partner_salary.fillna((df.Total_salary - df.Salary) ,inplace=True)

# %%
df[df['Total_salary']>150000].sort_values(by='Total_salary',ascending=True)
# Out:
#      Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 87    51    Male   Salaried        Married  Post Graduate                 3
# 57    54    Male   Business        Married  Post Graduate                 2
# 42    52  Female   Salaried        Married  Post Graduate                 3
# 117   47    Male   Salaried        Married       Graduate                 2
# 131   46    Male   Salaried        Married  Post Graduate                 3
# 277   41    Male   Salaried        Married  Post Graduate                 3
# 2     53  Female   Salaried        Married  Post Graduate                 3
# 329   39  Female   Salaried        Married  Post Graduate                 3
# 130   46  Female   Salaried        Married  Post Graduate                 3
# 19    49    Male   Salaried        Married  Post Graduate                 3
# 99    50    Male   Salaried        Married  Post Graduate                 3
# ...

# %%
df[df['Partner_working']=='No'].sort_values(by='Total_salary',ascending=False)
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 135    46  Female   Salaried        Married  Post Graduate                 3
# 53     52  Female   Salaried        Married  Post Graduate                 3
# 46     52  Female   Salaried        Married  Post Graduate                 4
# 80     52    Male   Business         Single  Post Graduate                 2
# 8      52    Male   Salaried        Married  Post Graduate                 4
# ...   ...     ...        ...            ...            ...               ...
# 1380   24    Male   Business        Married       Graduate                 3
# 1486   23     NaN   Salaried        Married       Graduate                 4
# 1381   24    Male   Business        Married       Graduate                 4
# 1382   24    Male   Business        Married       Graduate                 3
# 1383   24     NaN   Salaried         Single       Graduate                 2
#
# ...

# %%
df3 = df[df['Partner_working']=='No']
df3.describe()
# Out:
#              Age  No_of_Dependents        Salary  Partner_salary  \
# count  713.00000        713.000000    713.000000           713.0
# mean    32.13885          2.305750  60527.208976             0.0
# std      8.51826          0.988236  14155.715691             0.0
# min     22.00000          0.000000  30000.000000             0.0
# 25%     25.00000          2.000000  52400.000000             0.0
# 50%     29.00000          2.000000  60100.000000             0.0
# 75%     38.00000          3.000000  71800.000000             0.0
# max     54.00000          4.000000  90700.000000             0.0
#
#        Total_salary         Price
# count    713.000000    713.000000
# mean   60527.208976  36000.000000
# std    14155.715691  13817.734086
# min    30000.000000  18000.000000
# 25%    52400.000000  25000.000000
# 50%    60100.000000  31000.000000
# 75%    71800.000000  48000.000000
# max    90700.000000  70000.000000

# %%
df.sort_values(by='Total_salary',ascending=True)
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 1383   24     NaN   Salaried         Single       Graduate                 2
# 1382   24    Male   Business        Married       Graduate                 3
# 1381   24    Male   Business        Married       Graduate                 4
# 1486   23     NaN   Salaried        Married       Graduate                 4
# 1380   24    Male   Business        Married       Graduate                 3
# ...   ...     ...        ...            ...            ...               ...
# 29     46  Female   Salaried        Married  Post Graduate                 2
# 98     50  Female   Salaried        Married  Post Graduate                 4
# 0      53    Male   Business        Married  Post Graduate                 4
# 49     52  Female   Business        Married  Post Graduate                 4
# 56     51  Female   Salaried        Married  Post Graduate                 2
#
# ...

# %%
#df.Gender.mode()
# Imputing Missing Values in Gender with Mode as its a categorical Data 
df.Gender.fillna(df.Gender.mode()[0],inplace=True)

# %%
df.Gender.value_counts()
# Out:
# Male      1252
# Female     329
# Name: Gender, dtype: int64

# %%
df.isna().sum()
# Out:
# Age                 0
# Gender              0
# Profession          0
# Marital_status      0
# Education           0
# No_of_Dependents    0
# Personal_loan       0
# House_loan          0
# Partner_working     0
# Salary              0
# Partner_salary      0
# Total_salary        0
# Price               0
# Make                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1581 entries, 0 to 1580
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1581 non-null   int64
#  1   Gender            1581 non-null   object
#  2   Profession        1581 non-null   object
#  3   Marital_status    1581 non-null   object
#  4   Education         1581 non-null   object
#  5   No_of_Dependents  1581 non-null   int64
#  6   Personal_loan     1581 non-null   object
#  7   House_loan        1581 non-null   object
#  8   Partner_working   1581 non-null   object
#  9   Salary            1581 non-null   int64
#  10  Partner_salary    1581 non-null   float64
#  11  Total_salary      1581 non-null   int64
#  12  Price             1581 non-null   int64
#  13  Make              1581 non-null   object
# dtypes: float64(1), int64(5), object(8)
# memory usage: 173.0+ KB

# %%
df.sort_values(by='Partner_salary', ascending=True).head(10)
# NaN values in the Partner Salary has been replaced with 0.0
# Out:
#       Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 1580   22    Male   Salaried        Married       Graduate                 4
# 560    33    Male   Salaried        Married  Post Graduate                 2
# 561    33    Male   Salaried        Married  Post Graduate                 2
# 562    33    Male   Salaried        Married  Post Graduate                 1
# 563    33    Male   Business        Married  Post Graduate                 1
# 564    33  Female   Business         Single  Post Graduate                 2
# 565    33    Male   Salaried        Married       Graduate                 1
# 566    33    Male   Business        Married       Graduate                 2
# 567    33  Female   Salaried        Married       Graduate                 1
# 568    33    Male   Salaried        Married       Graduate                 1
#
#      Personal_loan House_loan Partner_working  Salary  Partner_salary  \
# ...

# %%
sns.pairplot(data=df)

# %%
sns.heatmap(df.corr(),annot=True)
# From the heat map we can conclude the following 
# 1. (Age, salary) ,(Age ,price) ,(total salary,salary) ,(partner salary, total salary) all appear  to be highly correlated >0.6
# 2. (Price,Salary) ,(total salary, price) and (age , total salary) seems to be moderately Correlated 0.2 - 0.6
# 3. otheres have little to no correlation
# Out:
# <AxesSubplot:>

# %%
num_df = df.select_dtypes(['int64','float64']).columns
obj_df = df.select_dtypes(['object']).columns

# %%
num_df
# Out:
# Index(['Age', 'No_of_Dependents', 'Salary', 'Partner_salary', 'Total_salary',
#        'Price'],
#       dtype='object')

# %%
obj_df
# Out:
# Index(['Gender', 'Profession', 'Marital_status', 'Education', 'Personal_loan',
#        'House_loan', 'Partner_working', 'Make'],
#       dtype='object')

# %%
# Ploting Box Plots for each of the Num data types
plt.figure(figsize = (14,9))
for i in range(0,len(num_df)):
    plt.subplot(3,2,i+1)
    sns.boxplot(df[num_df[i]])
plt.tight_layout()

# No_of_Dependents and Total_salary seem to have outliers , from the get go its clear that No of Dependents can be 0 so, not an outlier
# Total_salary outliers , we need to examine based on IQRs of Salary and Partner_salary

# %% [markdown]
# # Observations
# ## Median Age of customers seems to be in their Late 20s (29)
# ## Median No of Dependents is 2

# %%
def outlier_data(col):
    sorted(col)
    Q1,Q3 = col.quantile([0.25,0.75])
    IQR = Q3-Q1
    LL = Q1 - (1.5*IQR)
    UL = Q3 + (1.5*IQR)
    return LL,UL

# %%
outlier_data(df['Total_salary'])
# Out:
# (7400.0, 149000.0)

# %%
df[df['Total_salary']>150000].sort_values(by='Total_salary',ascending=False)
# From the above its clear that these are genuine outliers as both the Salary and Partner_salary seem to be towards the high end , which gives us a huge Total_Salary
# Out:
#      Age  Gender Profession Marital_status      Education  No_of_Dependents  \
# 56    51  Female   Salaried        Married  Post Graduate                 2
# 49    52  Female   Business        Married  Post Graduate                 4
# 0     53    Male   Business        Married  Post Graduate                 4
# 98    50  Female   Salaried        Married  Post Graduate                 4
# 29    46  Female   Salaried        Married  Post Graduate                 2
# 41    53  Female   Salaried        Married  Post Graduate                 4
# 116   47    Male   Business        Married       Graduate                 4
# 1     53  Female   Salaried        Married  Post Graduate                 4
# 17    49  Female   Salaried        Married  Post Graduate                 4
# 30    46    Male   Salaried        Married  Post Graduate                 4
# 75    52  Female   Salaried        Married  Post Graduate                 4
# ...

# %%
# Ploting Count Plots for each of the Object data types
plt.figure(figsize = (14,9))
for i in range(0,len(obj_df)):
    plt.subplot(3,3,i+1)
    sns.countplot(df[obj_df[i]])
plt.tight_layout()

# From the count plots the following observations can be infered 
# Most of the customers are Male
# Most of the customers are married and have a Working Partner 
# Sedan is their Top Selling Make , where as SUV is their Least Selling Make
# Most people don't have House Loan

# %%
df.groupby('Make')['Price'].sum()
# Out:
# Make
# Hatchback    15408000
# SUV          16580000
# Sedan        24292000
# Name: Price, dtype: int64

# %%
plt.subplot(2,2,1)
sns.countplot(data=df,x='Gender', hue='Education')
plt.subplot(2,2,2)
sns.countplot(data=df,x='Gender', hue='Profession')
# 1. Most of the customers are Male, Post-Graduates and are salaried
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
plt.subplot(2,2,1)
sns.countplot(data=df,x='Gender', hue='Personal_loan')
plt.subplot(2,2,2)
sns.countplot(data=df,x='Gender', hue='House_loan')
# 1.In Terms of Personal Loans, Male Customers often take Personal Loans compared to Female Customers
# 2. Both the gender seem to be not much intrested in House_loan
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
pd.crosstab(df['Gender'],df['Make']).plot(kind='bar')
plt.ylabel("Count")
plt.show()

# Male customers in general have a preference for Hatchbacks, followed by sedans a close 2nd and lastly SUV
# Female Customers on the other hand have a preference for SUVs followed by Sedans and lastly Hatchbacks

# %%
sns.countplot(data=df,x='Gender',hue='Make')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
pd.crosstab(df['Profession'],df['Make']).plot(kind='bar')
plt.ylabel("Count")
plt.show()
# A Salaried Person is more likely to Buy a Sedan

# %%
# Sheldon Cooper does not believe any of them; he claims that a salaried male is an easier target for a SUV sale over a Sedan Sale.
df_male = df[df['Gender']=='Male']
pd.crosstab(df_male['Profession'],df_male['Make']).plot(kind='bar')
plt.xlabel('Profession [Gender : Male]')
plt.ylabel("Count")
plt.show()

# Clamin is partially true  as its clear from the visualization that a Salaried Male is an easier target for a SUV sale , but also an easier target for Sedan Sale
# and total sales of Sedan > total sales of SUV for a Salaried ,Male customer

# %%
sns.boxplot(data=df,hue='Make',y='Price', x='Gender')
#SUV are the most explensive among the 3 makes followed by Sedans and lastly Hatchbacks
#Male customers often spend more on an SUV where as a female Customers spend more on a  Sedan, Hatchback
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Price'>

# %%
sns.boxplot(data=df,hue='Make',y='Price', x='Marital_status')
# Singles often spend on expensive Sedans
# Its also important to note that Median Price of SUV bought by both singles and Married people are same 
# Whereas Married people spend on a Expensive Hatchback
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='Price'>

# %%
sns.boxplot(data=df,hue='Gender',y='Price', x='Marital_status')
# Maaried People buy more expensive cars, cross both genders
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='Price'>

# %%
sns.boxplot(data=df,y='Price', x='Marital_status')
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='Price'>

# %%
sns.boxplot(data=df,hue='Make',y='Price',x='No_of_Dependents')
# The Price of SUV, hatchback bought is usually the more when the Number of Dependents is 4
# The price of Sedan bought is usually more when the Number of Dependents is 1
# Out:
# <AxesSubplot:xlabel='No_of_Dependents', ylabel='Price'>

# %%
sns.countplot(data=df, x='Make', hue='Gender')
#  Female Customers often account for greater SUVs Sales
# Male customers often account for Sedans , Hatchbacks
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %%
sns.countplot(data=df, x='Make', hue='Profession')
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %%
sns.boxplot(data=df,  y = 'Price',x='Profession')
# The median price of a Sedan, Hatchback purchased by Salaried customers is greater than Business Professionals
# The Median price spent by Business professionals on SUVs is far greater than their Salaried Counter parts
# Out:
# <AxesSubplot:xlabel='Profession', ylabel='Price'>

# %%
sns.boxplot(data=df, hue='Make', y = 'Price',x='Profession')
# Out:
# <AxesSubplot:xlabel='Profession', ylabel='Price'>

# %%
sns.boxplot(data=df,y='Price', x='Gender')
# Median Price of a Car bought by Female Customers is far greater than ther Male COunter parts
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Price'>

# %%
sns.boxplot(data=df,y='Price', x='Gender', hue='Personal_loan')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Price'>

# %%
sns.boxplot(data=df,y='Price', x='Personal_loan', hue ='Make')
# Median Price of Cars bought with out any personal loans is Higher
# The Median SUV Price and Median HatchBack Price of No Personal Loans is higher than those with personal loans
# Out:
# <AxesSubplot:xlabel='Personal_loan', ylabel='Price'>

# %%
sns.boxplot(data=df,y='Price', x='Personal_loan')
# Out:
# <AxesSubplot:xlabel='Personal_loan', ylabel='Price'>

# %%
sns.boxplot(data=df,y='Price', x='Partner_working', hue='Make')
# Majority of Customers with No Partner Working often buy slighly expensive Cars 
# Its also intresting to note that in  case of a working partner the median price of an Hatchback purchase is high
# Out:
# <AxesSubplot:xlabel='Partner_working', ylabel='Price'>

# %%
sns.boxplot(data=df,y='Price', x='Partner_working')
# Out:
# <AxesSubplot:xlabel='Partner_working', ylabel='Price'>

# %%
df.groupby('Gender')['Price'].sum()
# Out:
# Gender
# Female    15695000
# Male      40585000
# Name: Price, dtype: int64

# %%
df.groupby('Personal_loan')['Price'].sum()
# Out:
# Personal_loan
# No     28990000
# Yes    27290000
# Name: Price, dtype: int64

# %%
df[df['Partner_working']=='No']['Price'].max()
# Out:
# 70000

# %%
sns.boxplot(data=df,y='Price', x='Marital_status', hue='Make')
# Married people often spend more on a Hatchback and median price of SUV bought is also slightly higher 
# Where as Single Customers buy significantly more expensive sedans than their married counterparts
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='Price'>

# %%
sns.boxplot(data=df,y='Price', x='House_loan', hue='Make')
# Customers without any House Loan usually buy more expensive cars
# Although customers with house loans usually buy more expensice Hatchbacks
# Out:
# <AxesSubplot:xlabel='House_loan', ylabel='Price'>

# %%
sns.boxplot(data=df,y='Price', x='House_loan')
# Out:
# <AxesSubplot:xlabel='House_loan', ylabel='Price'>

# %%
sns.boxplot(data=df,y='Price', x='Education', hue='Make')
# Graduate customers often spend more on their car purchases
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Price'>

# %% [markdown]
# # GoDigit DataSet

# %%
godf = pd.read_excel('godigt.xlsx')

# %%
godf.head()
# Out:
#    userid              card_no  card_bin_no Issuer   card_type  \
# 0       1  4384 39XX XXXX XXXX       438439   Visa        edge
# 1       2  4377 48XX XXXX XXXX       437748   Visa  prosperity
# 2       3  4377 48XX XXXX XXXX       437748   Visa     rewards
# 3       4  4258 06XX XXXX XXXX       425806   Visa   indianoil
# 4       5  4377 48XX XXXX XXXX       437748   Visa        edge
#
#   card_source_date high_networth  active_30  active_60  active_90  ...  \
# 0       2019-09-29             B          0          1          1  ...
# 1       2002-10-30             A          1          1          1  ...
# 2       2013-10-05             C          0          0          0  ...
# 3       1999-06-01             E          0          1          1  ...
# 4       2006-06-13             B          1          1          1  ...
#
#    bank_vintage  T+1_month_activity  T+2_month_activity T+3_month_activity  \
# 0            27                   0                   0                  0
# ...

# %%
godf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8448 entries, 0 to 8447
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   userid                   8448 non-null   int64
#  1   card_no                  8448 non-null   object
#  2   card_bin_no              8448 non-null   int64
#  3   Issuer                   8448 non-null   object
#  4   card_type                8448 non-null   object
#  5   card_source_date         8448 non-null   datetime64[ns]
#  6   high_networth            8448 non-null   object
#  7   active_30                8448 non-null   int64
#  8   active_60                8448 non-null   int64
#  9   active_90                8448 non-null   int64
#  10  cc_active30              8448 non-null   int64
#  11  cc_active60              8448 non-null   int64
#  12  cc_active90              8448 non-null   int64
#  13  hotlist_flag             8448 non-null   object
# ...

# %%
godf.describe(include='all').T
# Out:
#                           count unique                  top  freq      first  \
# userid                   8448.0    NaN                  NaN   NaN        NaT
# card_no                    8448     11  4262 41XX XXXX XXXX  2084        NaT
# card_bin_no              8448.0    NaN                  NaN   NaN        NaT
# Issuer                     8448      3                 Visa  7279        NaT
# card_type                  8448     15              rewards  1502        NaT
# card_source_date           8448   5186  2008-12-04 00:00:00     6 1998-07-24
# high_networth              8448      5                    A  1740        NaT
# active_30                8448.0    NaN                  NaN   NaN        NaT
# active_60                8448.0    NaN                  NaN   NaN        NaT
# active_90                8448.0    NaN                  NaN   NaN        NaT
# cc_active30              8448.0    NaN                  NaN   NaN        NaT
# ...

# %%
godf.isnull().sum()
# So we have 38 Nulls in Tranactor_revolver
# Out:
# userid                      0
# card_no                     0
# card_bin_no                 0
# Issuer                      0
# card_type                   0
# card_source_date            0
# high_networth               0
# active_30                   0
# active_60                   0
# active_90                   0
# cc_active30                 0
# cc_active60                 0
# cc_active90                 0
# hotlist_flag                0
# widget_products             0
# engagement_products         0
# annual_income_at_source     0
# other_bank_cc_holding       0
# bank_vintage                0
# T+1_month_activity          0
# T+2_month_activity          0
# T+3_month_activity          0
# T+6_month_activity          0
# T+12_month_activity         0
# Transactor_revolver        38
# avg_spends_l3m              0
# Occupation_at_source        0
# cc_limit                    0
# dtype: int64

# %%
godf.duplicated().sum()
# No Duplicates
# Out:
# 0

# %%
godf.Issuer.unique()
# Out:
# array(['Visa', 'Mastercard', 'Amex'], dtype=object)

# %%
godf.card_type.unique()
# Out:
# array(['edge', 'prosperity', 'rewards', 'indianoil', 'cashback',
#        'shoprite', 'chartered', 'aura', 'gold', 'smartearn', 'prime',
#        'pulse', 'platinum', 'centurion', 'elite'], dtype=object)

# %%
godf.high_networth.unique()
# Out:
# array(['B', 'A', 'C', 'E', 'D'], dtype=object)

# %%
godf.Occupation_at_source.unique()
# 0 is not a valid Occupation
# Out:
# array(['Self Employed', 0, 'Student', 'Salaried', 'Retired', 'Housewife'],
#       dtype=object)

# %%
godf.Occupation_at_source.value_counts()
# Out:
# Salaried         3918
# Self Employed    2175
# Retired          1089
# Student           621
# Housewife         384
# 0                 261
# Name: Occupation_at_source, dtype: int64

# %%
# Here though card_bin_now and user id are int, there is no need of any arithmetic on them so can be conerted to category

godf['card_bin_no'] = godf['card_bin_no'].astype('object')

godf['userid'] = godf['userid'].astype('object')

# %%
godf.describe(include='all').T
# Out:
#                           count  unique                  top    freq  \
# userid                   8448.0  8448.0                  1.0     1.0
# card_no                    8448      11  4262 41XX XXXX XXXX    2084
# card_bin_no              8448.0    11.0             426241.0  2084.0
# Issuer                     8448       3                 Visa    7279
# card_type                  8448      15              rewards    1502
# card_source_date           8448    5186  2008-12-04 00:00:00       6
# high_networth              8448       5                    A    1740
# active_30                8448.0     NaN                  NaN     NaN
# active_60                8448.0     NaN                  NaN     NaN
# active_90                8448.0     NaN                  NaN     NaN
# cc_active30              8448.0     NaN                  NaN     NaN
# cc_active60              8448.0     NaN                  NaN     NaN
# cc_active90              8448.0     NaN                  NaN     NaN
# ...

# %%
godf['Transactor_revolver'].value_counts()
# Out:
# T    7115
# R    1295
# Name: Transactor_revolver, dtype: int64

# %%
godf[godf['Occupation_at_source']=='0'].describe(include='all')
# Out:
#        userid card_no card_bin_no Issuer card_type card_source_date  \
# count       0       0           0      0         0                0
# unique      0       0           0      0         0                0
# top       NaN     NaN         NaN    NaN       NaN              NaN
# freq      NaN     NaN         NaN    NaN       NaN              NaN
# mean      NaN     NaN         NaN    NaN       NaN              NaN
# std       NaN     NaN         NaN    NaN       NaN              NaN
# min       NaN     NaN         NaN    NaN       NaN              NaN
# 25%       NaN     NaN         NaN    NaN       NaN              NaN
# 50%       NaN     NaN         NaN    NaN       NaN              NaN
# 75%       NaN     NaN         NaN    NaN       NaN              NaN
# max       NaN     NaN         NaN    NaN       NaN              NaN
#
#        high_networth  active_30  active_60  active_90  ...  bank_vintage  \
# count              0        0.0        0.0        0.0  ...           0.0
# ...

# %%
godf['Occupation_at_source'] = godf['Occupation_at_source'].astype('object')

# %%
godf[godf['Occupation_at_source']==0].sort_values(by='T+1_month_activity', ascending =False)
# Out:
#      userid              card_no card_bin_no Issuer   card_type  \
# 524     525  4386 28XX XXXX XXXX      438628   Visa        edge
# 5874   5875  4384 39XX XXXX XXXX      438439   Visa        edge
# 5668   5669    37691 6XXXX XXXXX      376916   Amex   centurion
# 3174   3175  4377 48XX XXXX XXXX      437748   Visa        edge
# 5624   5625  4258 06XX XXXX XXXX      425806   Visa   chartered
# ...     ...                  ...         ...    ...         ...
# 3401   3402  4386 28XX XXXX XXXX      438628   Visa   chartered
# 3403   3404  4377 48XX XXXX XXXX      437748   Visa        edge
# 3515   3516  4262 41XX XXXX XXXX      426241   Visa  prosperity
# 3520   3521  4055 33XX XXXX XXXX      405533   Visa        edge
# 8443   8444  4262 41XX XXXX XXXX      426241   Visa   chartered
#
#      card_source_date high_networth  active_30  active_60  active_90  ...  \
# 524        2019-10-20             A          1          1          1  ...
# ...

# %%
godf['Sal_Flag'] = godf['active_30']+godf['active_60']+godf['active_90']
godf['CC_Flag'] = godf['cc_active30']+godf['cc_active60']+godf['cc_active90']
godf['Cust_Spends_CC_Flag'] = godf['T+1_month_activity']+godf['T+2_month_activity']+godf['T+3_month_activity']+godf['T+6_month_activity']+godf['T+12_month_activity']

# %%
godf.describe(include='all').T
# Here higher the Sal_Flag Number the more the person saves money / has an active source to pay back credit card dues
# Here high number for CC_Flag indicates high credit card actiity
# here high number for Cust_Spends_CC_Flag  indicates that credit card is more frequenly used for spends
# Out:
#                           count  unique                  top    freq  \
# userid                   8448.0  8448.0                  1.0     1.0
# card_no                    8448      11  4262 41XX XXXX XXXX    2084
# card_bin_no              8448.0    11.0             426241.0  2084.0
# Issuer                     8448       3                 Visa    7279
# card_type                  8448      15              rewards    1502
# card_source_date           8448    5186  2008-12-04 00:00:00       6
# high_networth              8448       5                    A    1740
# active_30                8448.0     NaN                  NaN     NaN
# active_60                8448.0     NaN                  NaN     NaN
# active_90                8448.0     NaN                  NaN     NaN
# cc_active30              8448.0     NaN                  NaN     NaN
# cc_active60              8448.0     NaN                  NaN     NaN
# cc_active90              8448.0     NaN                  NaN     NaN
# ...

# %%
godf.Transactor_revolver.fillna(godf.Transactor_revolver.mode()[0],inplace=True)

# %%
num_godf = godf.select_dtypes(exclude = ['datetime64','object']).columns
obj_godf = godf.select_dtypes(['datetime64','object']).columns

# %%
num_godf
# Out:
# Index(['active_30', 'active_60', 'active_90', 'cc_active30', 'cc_active60',
#        'cc_active90', 'widget_products', 'engagement_products',
#        'annual_income_at_source', 'bank_vintage', 'T+1_month_activity',
#        'T+2_month_activity', 'T+3_month_activity', 'T+6_month_activity',
#        'T+12_month_activity', 'avg_spends_l3m', 'cc_limit', 'Sal-Flag',
#        'Sal_Flag', 'CC_Flag', 'Cust_Spends_CC_Flag'],
#       dtype='object')

# %%
obj_godf
# Out:
# Index(['userid', 'card_no', 'card_bin_no', 'Issuer', 'card_type',
#        'card_source_date', 'high_networth', 'hotlist_flag',
#        'other_bank_cc_holding', 'Transactor_revolver', 'Occupation_at_source'],
#       dtype='object')

# %%
godf.drop(['active_30', 'active_60', 'active_90','cc_active30', 'cc_active60','cc_active90','T+1_month_activity',
       'T+2_month_activity', 'T+3_month_activity', 'T+6_month_activity','T+12_month_activity'],inplace = True , axis=1)

# %%
plt.figure(figsize=(14,9))
sns.heatmap(godf.corr(),annot=True)
plt.tight_layout()

# %%
plt.figure(figsize=(14,9))
sns.boxplot(data=godf, y='avg_spends_l3m',hue='card_type', x = 'Issuer')
plt.tight_layout()
# Average spends in last 3 months on credit card is generally high when card type is centurion and Issuer is Amex

# %%
#plt.figure(figsize=(14,9))
sns.boxplot(data=godf, y='avg_spends_l3m', x = 'Occupation_at_source')
plt.tight_layout()
# Average Spends seems to be higher for category 0 Occupation customers

# %%
sns.boxplot(data=godf, y='annual_income_at_source',hue='Transactor_revolver', x = 'Occupation_at_source')
plt.tight_layout()
# People who are Student and Salaried are significantly likely to be Transactor(ie Pay due amounts, within due date)
#Retied customers also seem to be Transactor , where as rest are Revolvers

# %%
sns.boxplot(data=godf, y='high_networth',hue='Transactor_revolver', x = 'cc_limit')
plt.tight_layout()
# People with high networths , have higher CC limits

# %%
sns.boxplot(data=godf, y='avg_spends_l3m', x = 'widget_products')
plt.tight_layout()
# Number of widgets seems to have not much apparent out come

# %%
sns.boxplot(data=godf, y='avg_spends_l3m', x = 'engagement_products')
plt.tight_layout()
#Number of engagement_products seems to have not much apparent out come

# %%
sns.boxplot(data=godf, y='annual_income_at_source',hue='hotlist_flag', x = 'high_networth')
plt.tight_layout()
# Ususally customers from income bracket C , tend to hotlist their cards

# %%
sns.boxplot(data=godf, y='avg_spends_l3m',hue='hotlist_flag', x = 'other_bank_cc_holding')
plt.tight_layout()
# Average spend is usually higher  when hotlisting is No and holding other bank credit card does'nt affect the average spends ,as much

# %%
sns.boxplot(data=godf, y='avg_spends_l3m',x='Cust_Spends_CC_Flag')
plt.tight_layout()

# %%
sns.boxplot(data=godf, y='avg_spends_l3m',x='CC_Flag')
plt.tight_layout()
# so no of times a credit card was used to make payments is not that significant

# %%
sns.boxplot(data=godf, y='avg_spends_l3m',x='Sal-Flag')
plt.tight_layout()
# Salary activities across months are also not that useful

# %%
sns.boxplot(data=godf, x='CC_Flag',y='bank_vintage')
plt.tight_layout()

# %%
sns.boxplot(data=godf, x='Transactor_revolver',y='bank_vintage', hue='hotlist_flag')
plt.tight_layout()
#

# %%
sns.boxplot(data=godf, y='annual_income_at_source',hue='Occupation_at_source', x = 'high_networth')
plt.tight_layout()

# %%
#plt.figure(figsize=(14,9))
sns.boxplot(data=godf, y='avg_spends_l3m', x = 'high_networth')
plt.tight_layout()

# %%
pd.crosstab(godf['high_networth'],godf['card_type'])
# Out:
# card_type      aura  cashback  centurion  chartered  edge  elite  gold  \
# high_networth
# A                 0         0         33        488   514     48    29
# B                 0         0         29        435   466     48    32
# C               218       201          0          0     0      0    26
# D               214       255          0          0     0      0    34
# E               220       220          0          0     0      0    24
#
# card_type      indianoil  platinum  prime  prosperity  pulse  rewards  \
# high_networth
# A                      0        27     52         498     51        0
# B                      0        32     59         509     50        0
# C                    225         0      0           0      0      518
# D                    221         0      0           0      0      516
# E                    234         0      1           0      0      468
#
# card_type      shoprite  smartearn
# high_networth
# ...
